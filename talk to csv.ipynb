# %%
import pandas as pd

# %%
from pandasai import SmartDataframe
from pandasai.llm import OpenAI

llm = OpenAI(api_token="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")

# You can instantiate a SmartDataframe with a path to a CSV file
df = SmartDataframe(r"C:\Users\jayma\Documents\Sound Recordings\Real_CRM_Data.csv", config={"llm": llm})

response = df.chat("plot a scatter plot between User Activity and Deal Value")
print(response)
# Out:
# C:/Users/jayma/exports/charts/temp_chart.png

# %%
df
# Out:
#      Unnamed: 0                User                  Profile Picture  \
# 0             0     Savannah Cortez   https://dummyimage.com/646x621
# 1             1    John Anderson MD    https://dummyimage.com/22x532
# 2             2        Amy Williams   https://dummyimage.com/619x819
# 3             3           John Reed  https://placekitten.com/759/542
# 4             4       Ashley Castro  https://placekitten.com/616/765
# ..          ...                 ...                              ...
# 495         495         Lance Combs  https://dummyimage.com/660x1024
# 496         496     Christina Moran  https://placekitten.com/911/745
# 497         497         James Mills   https://placekitten.com/23/153
# 498         498  Brianna Washington  https://placekitten.com/927/399
# 499         499     Crystal Jenkins  https://placekitten.com/554/392
#
#                    Email Address           Phone Number  \
# 0         jennifer06@example.net          (958)861-5017
# 1         alexthomas@example.org          (981)737-7214
# 2        carlabrooks@example.org           976.520.3848
# 3     jonathansantos@example.net           951.685.7053
# 4           rflowers@example.net  +1-490-956-2702x75637
# ..                           ...                    ...
# 495       julieortiz@example.com          (962)817-5474
# 496  gonzalezvanessa@example.com   +1-677-424-3210x4870
# 497             scox@example.net      700.288.6282x5660
# 498     rivasdeborah@example.net      684-518-4057x6883
# 499      rangeltonya@example.org    +1-964-748-3700x176
#
#                                  Communication History  \
# 0    As order general party. Past close against top...
# 1     Human must trial family. Break return bill line.
# 2    Seek such agreement head whatever effort hear....
# 3    Past plan daughter service. Discuss party pass...
# 4    Person case level culture executive. Main rest...
# ..                                                 ...
# 495  True record large than economic special. Parti...
# 496  Guess really bad common community. Bring diffe...
# 497  Forget second feeling environmental. Thank its...
# 498  Least weight matter fast. Show data land socia...
# 499         Structure person because. Line story able.
#
#                       Company Name    Industry   Deal Stage  Deal Value  \
# 0                       Turner PLC  Healthcare  Opportunity       50107
# 1     Anthony, Chen and Harrington      Retail  Opportunity       76552
# 2    Matthews, Barajas and Harrell      Retail  Opportunity       90696
# 3                      Johnson PLC  Healthcare         Lead       99223
# 4                   Williams-Nixon  Healthcare  Opportunity       47473
# ..                             ...         ...          ...         ...
# 495                     Smith-Bell      Retail  Closed Deal       78180
# 496                   Cochran-Wood      Retail     Proposal       74573
# 497                   Dalton-Clark     Finance  Closed Deal       30179
# 498                   Martinez Inc      Retail  Closed Deal        1893
# 499                   Mitchell Ltd      Retail  Opportunity       75336
#
#     Win/Loss Status Upcoming Tasks Activity Status Lead Source  \
# 0              Lost     12/30/2023         Ongoing       Yahoo
# 1              Lost      1/23/2024       Completed       Other
# 2              Lost      1/18/2024              o            X
# 3              Lost      1/21/2024              o        Other
# 4               Won      1/14/2024              o     Facebook
# ..              ...            ...             ...         ...
# 495            Lost      1/19/2024       Completed      Google
# 496             Won       1/5/2024         Ongoing   Instagram
# 497            Lost      1/24/2024         Ongoing    Facebook
# 498            Lost      1/10/2024         Ongoing           X
# 499            Lost      1/12/2024       Completed       Other
#
#                                          Location  Custom Visuals  \
# 0                                           Spain               6
# 1                                          Jordan               3
# 2                                         Tokelau               9
# 3                                          Kuwait               3
# 4                                          Jersey               1
# ..                                            ...             ...
# 495                                         Congo               6
# 496  Antarctica (the territory South of 60 deg S)              10
# 497                           Trinidad and Tobago               5
# 498                                     Argentina               6
# 499                                        Turkey               5
#
#     Creation Date Last Updated  User Activity
# 0       2/15/2021   12/19/2023           24.0
# 1       8/26/2021   12/20/2023           41.0
# 2       7/15/2022    12/2/2023           88.0
# 3        2/6/2020   12/23/2023           47.0
# 4        2/6/2021    12/6/2023           71.0
# ..            ...          ...            ...
# 495     9/19/2023   12/20/2023           94.0
# 496      2/9/2021    12/3/2023           75.0
# 497    10/27/2020   12/11/2023           36.0
# 498    10/10/2021    12/8/2023           52.0
# 499    10/11/2023   12/14/2023           89.0
#
# [500 rows x 19 columns]

# %%
#summarize the text
import pandas as pd
import requests
API_KEY = "AIzaSyD06hfuWNVeyMTnPWNui1mjT3zUIGxTNuE"  # Replace with your actual API key
#bard
# Get user input for the base prompt
base_prompt = input("Enter the base prompt: ")

# Get user input for the variable instruction
variable_instruction ='''
summarize the give text in casual understandable language in short form
'''
# Combine the base prompt and variable instruction in the desired format
prompt = f"{base_prompt} {variable_instruction}"

# Create the data dictionary with the modified prompt
data = {
  "contents": [
      {"role": "user", "parts": [{"text": prompt}]}
  ]
}

headers = {"Content-Type": "application/json"}

response = requests.post(
  'https://generativelanguage.googleapis.com/v1/models/gemini-pro:generateContent?key='
  + API_KEY,
  headers=headers,
  json=data,
)

if response.status_code == 200:
    
    response_json = response.json()

# Accessing the generated content
    candidates = response_json.get("candidates", [])
    if candidates:
        
        generated_text = candidates[0].get("content", {}).get("parts", [])[0].get("text", "")

        if generated_text:
                
            print("Generated text:", generated_text)
        else:
            
            print("No 'text' key found in the response structure.")
    else:
            
        print("No candidates found in the response.")
else:
        
    print("API request failed with status code:", response.status_code)
# Out:
# Enter the base prompt: It issued a major tsunami warning for Ishikawa and lower-level tsunami warnings or advisories for the rest of the northwestern coast of the island of Honshu.  “All residents must evacuate immediately to higher ground,” public broadcaster NHK said after the quake hit the Noto region in Ishikawa prefecture around 4:10pm local time (07:10 GMT).  Hazardous tsunami waves of up to five metres high (16.5 feet) were possible along the north coast of central Japan within 300km (186 miles) of a magnitude 7.5 quake’s epicentre, US and Japanese agencies said.  Waves more than one metre high (3.3 feet) hit the coast of Wajima City in Ishikawa, NHK reported. It said another earthquake warning has been issued for Ishikawa.  Chief cabinet secretary Yoshimasa Hayashi said there were no abnormalities reported in nuclear plants after the earthquake, but warned residents to prepare for possible further quakes.  Buildings began to sway in the area around the capital Tokyo. There were initially no reports of damage or casualties.  The government said no abnormalities were reported in nuclear plants after the earthquake.  South Korea’s meteorological agency said the sea level in some parts of the Gangwon province on the east coast may rise.
# Generated text: A major earthquake struck Ishikawa, Japan causing tsunami warnings for the northwest coast of Honshu Island. Residents were advised to evacuate to higher ground. Tsunami waves up to five meters high were possible within 300km of the epicenter. Waves over one meter high hit the coast of Wajima City. There were no immediate reports of damage or casualties.

# %%
It issued a major tsunami warning for Ishikawa and lower-level tsunami warnings or advisories for the rest of the northwestern coast of the island of Honshu.

“All residents must evacuate immediately to higher ground,” public broadcaster NHK said after the quake hit the Noto region in Ishikawa prefecture around 4:10pm local time (07:10 GMT).

Hazardous tsunami waves of up to five metres high (16.5 feet) were possible along the north coast of central Japan within 300km (186 miles) of a magnitude 7.5 quake’s epicentre, US and Japanese agencies said.

Waves more than one metre high (3.3 feet) hit the coast of Wajima City in Ishikawa, NHK reported. It said another earthquake warning has been issued for Ishikawa.

Chief cabinet secretary Yoshimasa Hayashi said there were no abnormalities reported in nuclear plants after the earthquake, but warned residents to prepare for possible further quakes.

Buildings began to sway in the area around the capital Tokyo. There were initially no reports of damage or casualties.

The government said no abnormalities were reported in nuclear plants after the earthquake.

South Korea’s meteorological agency said the sea level in some parts of the Gangwon province on the east coast may rise.
